# %%
import pandas as pd
import pymysql as sql
db = sql.connect(host='localhost',user='root',password='abhiyadav;',database='Abhi')
s=pd.read_sql_query('SELECT * FROM student',con=db)
k=[2,4]
s['tax']=k

s.drop(['tax'],axis=1)
s.drop([0],axis=0)
s
# Out:
# C:\Users\ABHISHEK YADAV\AppData\Local\Temp\ipykernel_2376\3024733994.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   s=pd.read_sql_query('SELECT * FROM student',con=db)
#    id  name  tax
# 0   1  Abhi    2
# 1   2   Ram    4

# %%
df=pd.read_csv(r"C:\Users\ABHISHEK YADAV\Downloads\Canadian-Earthquakes-2010-2019.csv")
df['Ranking']=df['depth'].rank().astype('int')
df
# Out:
#       magnitude_codelist  magnitude magnitude_type                      date  \
# 0                     <2        1.7             ML  2010-01-01T00:16:49+0000
# 1                      2        2.2             MN  2010-01-01T00:52:50+0000
# 2                     <2        1.8             MN  2010-01-01T03:21:58+0000
# 3                     <2        1.5             MN  2010-01-01T04:14:51+0000
# 4                     <2        1.6             ML  2010-01-01T04:15:17+0000
# ...                  ...        ...            ...                       ...
# 44556                 <2        1.8             ML  2019-12-31T18:37:24+0000
# 44557                  2        2.4             MN  2019-12-31T22:18:53+0000
# 44558                  2        2.0             ML  2019-12-31T23:11:07+0000
# 44559                 <2        1.9             MN  2019-12-31T23:53:23+0000
# 44560                 <2        1.3             MN  2019-12-31T23:54:02+0000
#
# ...

# %%
class student:
    def __init__(self,marks):
        self.marks=marks
        
    def yadav(self):
        return print(f"{self.marks}this is the total marks of the student")

class rakesh(student):
    def nidhi(self):
        return print(f"this is the other class but the valaue are the same{self.marks}this")
# parent=student()
rakhi=rakesh(50)
rakhi.nidhi()
# parent.yadav()
# Out:
# this is the other class but the valaue are the same50this

# %%
list =[2,5,3,6,6,4]
a=list.count(6)
print(a)
# Out:
# 2

# %%
my_list = [2, 5, 3, 6, 4, 3]
my_list.append(200000)
print(my_list)
# Out:
# [2, 5, 3, 6, 4, 3, 200000]

# %%
my_list = [2, 5, 3, 6, 4, 3]
my_list.extend([2,5,5,7,8,3])
my_list
# Out:
# [2, 5, 3, 6, 4, 3, 2, 5, 5, 7, 8, 3]

# %%
df=pd.read_csv(r"C:\Users\ABHISHEK YADAV\Downloads\employee_salary_dataset.csv")
# df.loc[2]=[3,'Abhishek_Yadav','IT',15,'Masters',24,'Male','Ghaziabad',28436]
# df['Ranking']=df['Monthly_Salary'].rank().astype('int') 

# df['Dens_Ranking']=df['Monthly_Salary'].rank(method='dense').astype('int') 
# df=df.sort_values(by='Ranking')

df.head(15)
df
# Out:
#     EmployeeID         Name  Department  Experience_Years Education_Level  \
# 0            1   Employee_1   Marketing                15          Master
# 1            2   Employee_2  Operations                 7        Bachelor
# 2            3   Employee_3          IT                12     High School
# 3            4   Employee_4  Operations                 8             PhD
# 4            5   Employee_5  Operations                15          Master
# 5            6   Employee_6     Finance                 3     High School
# 6            7   Employee_7          IT                14             PhD
# 7            8   Employee_8          IT                17             PhD
# 8            9   Employee_9          IT                 4        Bachelor
# 9           10  Employee_10  Operations                18     High School
# 10          11  Employee_11   Marketing                 8             PhD
# 11          12  Employee_12          IT                 4          Master
# ...

# %%
df[(df['Monthly_Salary']>=50000)&(df['Monthly_Salary']<=60000)]
# Out:
#     EmployeeID         Name Department  Experience_Years Education_Level  Age  \
# 18          19  Employee_19         HR                 2             PhD   32
# 44          45  Employee_45    Finance                 8          Master   53
# 46          47  Employee_47    Finance                 3          Master   22
#
#     Gender     City  Monthly_Salary
# 18    Male  Chennai           55746
# 44    Male    Delhi           57635
# 46  Female    Delhi           58828

# %%
df
df[df['Name'].isin(['Abhishek_Yadav','Employee_14','Employee_17','Employee_10','Employee_49'])]
# Out:
#     EmployeeID         Name  Department  Experience_Years Education_Level  \
# 9           10  Employee_10  Operations                18     High School
# 13          14  Employee_14     Finance                 6        Bachelor
# 16          17  Employee_17   Marketing                18          Master
# 48          49  Employee_49     Finance                 5             PhD
#
#     Age  Gender       City  Monthly_Salary
# 9    28    Male     Mumbai           31893
# 13   27    Male      Delhi           28436
# 16   41  Female  Hyderabad           30895
# 48   23  Female  Hyderabad           28420

# %%
df
df[~df['Name'].isin(['Abhishek_Yadav','Employee_14','Employee_17','Employee_10','Employee_49'])]
# Out:
#     EmployeeID         Name  Department  Experience_Years Education_Level  \
# 0            1   Employee_1   Marketing                15          Master
# 1            2   Employee_2  Operations                 7        Bachelor
# 2            3   Employee_3          IT                12     High School
# 3            4   Employee_4  Operations                 8             PhD
# 4            5   Employee_5  Operations                15          Master
# 5            6   Employee_6     Finance                 3     High School
# 6            7   Employee_7          IT                14             PhD
# 7            8   Employee_8          IT                17             PhD
# 8            9   Employee_9          IT                 4        Bachelor
# 10          11  Employee_11   Marketing                 8             PhD
# 11          12  Employee_12          IT                 4          Master
# 12          13  Employee_13  Operations                 2          Master
# ...

# %%
df
# y=df['Department'].unique()
# y
# df['Department'].value_counts()
# l=df.set_index('Department')
# l
df[df['Department'].str.startswith('I')]
#
# Out:
#     EmployeeID         Name Department  Experience_Years Education_Level  Age  \
# 2            3   Employee_3         IT                12     High School   51
# 6            7   Employee_7         IT                14             PhD   57
# 7            8   Employee_8         IT                17             PhD   34
# 8            9   Employee_9         IT                 4        Bachelor   53
# 11          12  Employee_12         IT                 4          Master   49
# 25          26  Employee_26         IT                14          Master   24
# 26          27  Employee_27         IT                 8        Bachelor   27
# 30          31  Employee_31         IT                15        Bachelor   54
# 34          35  Employee_35         IT                13          Master   53
# 36          37  Employee_37         IT                 7     High School   33
#
#     Gender       City  Monthly_Salary
# 2   Female  Hyderabad           69064
# ...

# %%
# t=df['Department'].unique()
# t
df[df['Department']=='IT'].count()
# df.rename(rows={'Abhishek_Yadav':'Abhishek'})
# df['Department'].value_counts(['IT'])
# df.iloc[0:5,1:5]
# df['department_years']=df['Department']+df['Experience_Years'].astype(str)
# df
# df.iloc[16:17]
# df
# df[df['Education_Level'].str.len()3]
# Out:
# EmployeeID          10
# Name                10
# Department          10
# Experience_Years    10
# Education_Level     10
# Age                 10
# Gender              10
# City                10
# Monthly_Salary      10
# dtype: int64

# %%
#map()
#apply()
#apply map()
df
df['persentage']=df['Monthly_Salary']/10000
df
# Out:
#     EmployeeID         Name  Department  Experience_Years Education_Level  \
# 0            1   Employee_1   Marketing                15          Master
# 1            2   Employee_2  Operations                 7        Bachelor
# 2            3   Employee_3          IT                12     High School
# 3            4   Employee_4  Operations                 8             PhD
# 4            5   Employee_5  Operations                15          Master
# 5            6   Employee_6     Finance                 3     High School
# 6            7   Employee_7          IT                14             PhD
# 7            8   Employee_8          IT                17             PhD
# 8            9   Employee_9          IT                 4        Bachelor
# 9           10  Employee_10  Operations                18     High School
# 10          11  Employee_11   Marketing                 8             PhD
# 11          12  Employee_12          IT                 4          Master
# ...

# %%
h=df.groupby(['Department'])
h

# %%
for i,j in h:
    print(i)
    print(j)
# Out:
# ('Finance',)
#     EmployeeID         Name Department  Experience_Years Education_Level  Age  \
# 5            6   Employee_6    Finance                 3     High School   50
# 13          14  Employee_14    Finance                 6        Bachelor   27
# 15          16  Employee_16    Finance                 4     High School   49
# 20          21  Employee_21    Finance                 4          Master   46
# 27          28  Employee_28    Finance                16          Master   29
# 39          40  Employee_40    Finance                12        Bachelor   38
# 43          44  Employee_44    Finance                17          Master   44
# 44          45  Employee_45    Finance                 8          Master   53
# 46          47  Employee_47    Finance                 3          Master   22
# 48          49  Employee_49    Finance                 5             PhD   23
#
#     Gender       City  Monthly_Salary  persentage
# ...

# %%
y=h['Monthly_Salary'].sum()
y
# Out:
# Department
# Finance        672619
# HR             580616
# IT             765205
# Marketing     1253601
# Operations     842399
# Name: Monthly_Salary, dtype: int64

# %%
k=pd.DataFrame(y)
k
# k['Monthly_Salary'].count()
# Out:
#             Monthly_Salary
# Department
# Finance             672619
# HR                  580616
# IT                  765205
# Marketing          1253601
# Operations          842399

# %%
# k[['Department','IT']].count()
# b=k[k['Department']=='IT']
# b
y=df[df['Department'] == 'IT'].value_counts()
z=pd.DataFrame(y)
z
# Out:
#                                                                                                                    count
# EmployeeID Name        Department Experience_Years Education_Level Age Gender City      Monthly_Salary persentage
# 3          Employee_3  IT         12               High School     51  Female Hyderabad 69064          6.9064          1
# 7          Employee_7  IT         14               PhD             57  Male   Mumbai    70525          7.0525          1
# 8          Employee_8  IT         17               PhD             34  Female Bangalore 44830          4.4830          1
# 9          Employee_9  IT         4                Bachelor        53  Male   Hyderabad 42429          4.2429          1
# 12         Employee_12 IT         4                Master          49  Female Hyderabad 104909         10.4909         1
# 26         Employee_26 IT         14               Master          24  Male   Hyderabad 30600          3.0600          1
# ...

# %%
df[df.Monthly_Salary==df['Monthly_Salary'].max()]
df[df['Monthly_Salary']>130000]
# Out:
#     EmployeeID         Name  Department  Experience_Years Education_Level  \
# 4            5   Employee_5  Operations                15          Master
# 10          11  Employee_11   Marketing                 8             PhD
# 24          25  Employee_25          HR                 8     High School
# 33          34  Employee_34          HR                15        Bachelor
# 34          35  Employee_35          IT                13          Master
# 37          38  Employee_38  Operations                 9          Master
#
#     Age  Gender       City  Monthly_Salary  persentage
# 4    36  Female      Delhi          132450     13.2450
# 10   43    Male      Delhi          141381     14.1381
# 24   34  Female  Bangalore          132455     13.2455
# 33   53  Female      Delhi          134616     13.4616
# 34   53    Male  Bangalore          130983     13.0983
# 37   23    Male     Mumbai          149123     14.9123

# %%
import matplotlib.pyplot as plt

s=df.groupby(['Department','Education_Level'])
s.plot(kind='bar',color=['purple','yellow'])
plt.title('total revenue by day')
plt.xlabel('day')
plt.ylabel('total revenue')
plt.show()
# for i,j in s:
#     print(i)
#     print(j)

# %%
df[
    (df['Department'] == 'IT') &
    (df['Education_Level'] == 'Bachelor')
]
# Out:
#     EmployeeID         Name Department  Experience_Years Education_Level  Age  \
# 8            9   Employee_9         IT                 4        Bachelor   53
# 26          27  Employee_27         IT                 8        Bachelor   27
# 30          31  Employee_31         IT                15        Bachelor   54
#
#     Gender       City  Monthly_Salary  persentage
# 8     Male  Hyderabad           42429      4.2429
# 26  Female      Delhi          119660     11.9660
# 30  Female  Hyderabad           70714      7.0714

# %%
s=df['Monthly_Salary']
s2=list(s)
s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 s=df['Monthly_Salary']
# ----> 2 s2=list(s)
#       3 s2
#
# TypeError: 'list' object is not callable

# %%
df.groupby('Department')
