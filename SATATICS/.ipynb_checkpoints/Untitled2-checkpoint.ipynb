# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel(r"C:\Users\ABHISHEK YADAV\Downloads\Pizza_Sales.xlsx")
df
# Out:
#        order_details_id  order_id       pizza_id  quantity order_date  \
# 0                     1         1     hawaiian_m         1 2015-01-01
# 1                     2         2  classic_dlx_m         1 2015-01-01
# 2                     3         2  five_cheese_l         1 2015-01-01
# 3                     4         2    ital_supr_l         1 2015-01-01
# 4                     5         2     mexicana_m         1 2015-01-01
# ...                 ...       ...            ...       ...        ...
# 48615             48616     21348  ckn_alfredo_m         1 2015-12-31
# 48616             48617     21348  four_cheese_l         1 2015-12-31
# 48617             48618     21348   napolitana_s         1 2015-12-31
# 48618             48619     21349     mexicana_l         1 2015-12-31
# 48619             48620     21350      bbq_ckn_s         1 2015-12-31
#
#       order_time  unit_price  total_price pizza_size pizza_category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_details_id   48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_id           48620 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  datetime64[ns]
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48620 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48620 non-null  object
#  10  pizza_ingredients  48620 non-null  object
#  11  pizza_name         48620 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(6)
# memory usage: 4.5+ MB

# %%
df.isnull().sum()
# Out:
# order_details_id     0
# order_id             0
# pizza_id             0
# quantity             0
# order_date           0
# order_time           0
# unit_price           0
# total_price          0
# pizza_size           0
# pizza_category       0
# pizza_ingredients    0
# pizza_name           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_details_id   48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_id           48620 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  datetime64[ns]
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48620 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48620 non-null  object
#  10  pizza_ingredients  48620 non-null  object
#  11  pizza_name         48620 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(6)
# memory usage: 4.5+ MB

# %%
df['pizza_size'].unique()
# Out:
# array(['M', 'L', 'S', 'XL', 'XXL'], dtype=object)

# %%
size_map={"S":1,"M":2,"L":3,"XL":4,"XXl":5}
df["pizza_size"]=df["pizza_size"].map(size_map)

# %%
df
# Out:
#        order_details_id  order_id       pizza_id  quantity order_date  \
# 0                     1         1     hawaiian_m         1 2015-01-01
# 1                     2         2  classic_dlx_m         1 2015-01-01
# 2                     3         2  five_cheese_l         1 2015-01-01
# 3                     4         2    ital_supr_l         1 2015-01-01
# 4                     5         2     mexicana_m         1 2015-01-01
# ...                 ...       ...            ...       ...        ...
# 48615             48616     21348  ckn_alfredo_m         1 2015-12-31
# 48616             48617     21348  four_cheese_l         1 2015-12-31
# 48617             48618     21348   napolitana_s         1 2015-12-31
# 48618             48619     21349     mexicana_l         1 2015-12-31
# 48619             48620     21350      bbq_ckn_s         1 2015-12-31
#
#       order_time  unit_price  total_price  pizza_size pizza_category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_details_id   48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_id           48620 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  datetime64[ns]
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48620 non-null  float64
#  8   pizza_size         48592 non-null  float64
#  9   pizza_category     48620 non-null  object
#  10  pizza_ingredients  48620 non-null  object
#  11  pizza_name         48620 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(3), object(5)
# memory usage: 4.5+ MB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["pizza_category"].unique()
# Out:
# array(['Classic', 'Veggie', 'Supreme', 'Chicken'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df["pizza_category"]=encoder.fit_transform(df["pizza_category"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_details_id   48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_id           48620 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  datetime64[ns]
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48620 non-null  float64
#  8   pizza_size         48592 non-null  float64
#  9   pizza_category     48620 non-null  int64
#  10  pizza_ingredients  48620 non-null  object
#  11  pizza_name         48620 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(4), object(4)
# memory usage: 4.5+ MB

# %%
df
# Out:
#        order_details_id  order_id       pizza_id  quantity order_date  \
# 0                     1         1     hawaiian_m         1 2015-01-01
# 1                     2         2  classic_dlx_m         1 2015-01-01
# 2                     3         2  five_cheese_l         1 2015-01-01
# 3                     4         2    ital_supr_l         1 2015-01-01
# 4                     5         2     mexicana_m         1 2015-01-01
# ...                 ...       ...            ...       ...        ...
# 48615             48616     21348  ckn_alfredo_m         1 2015-12-31
# 48616             48617     21348  four_cheese_l         1 2015-12-31
# 48617             48618     21348   napolitana_s         1 2015-12-31
# 48618             48619     21349     mexicana_l         1 2015-12-31
# 48619             48620     21350      bbq_ckn_s         1 2015-12-31
#
#       order_time  unit_price  total_price  pizza_size  pizza_category  \
# ...

# %%
df["order_time"] = pd.to_datetime(df["order_time"].astype(str))
df["hour"] = df["order_time"].dt.hour
# Out:
# C:\Users\ABHISHEK YADAV\AppData\Local\Temp\ipykernel_15520\3652403136.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["order_time"] = pd.to_datetime(df["order_time"].astype(str))

# %%
df
# Out:
#        order_details_id  order_id       pizza_id  quantity order_date  \
# 0                     1         1     hawaiian_m         1 2015-01-01
# 1                     2         2  classic_dlx_m         1 2015-01-01
# 2                     3         2  five_cheese_l         1 2015-01-01
# 3                     4         2    ital_supr_l         1 2015-01-01
# 4                     5         2     mexicana_m         1 2015-01-01
# ...                 ...       ...            ...       ...        ...
# 48615             48616     21348  ckn_alfredo_m         1 2015-12-31
# 48616             48617     21348  four_cheese_l         1 2015-12-31
# 48617             48618     21348   napolitana_s         1 2015-12-31
# 48618             48619     21349     mexicana_l         1 2015-12-31
# 48619             48620     21350      bbq_ckn_s         1 2015-12-31
#
#                order_time  unit_price  total_price  pizza_size  \
# ...

# %%
df2=df.select_dtypes(["int", "float"])
df2
# Out:
#        order_details_id  order_id  quantity  unit_price  total_price  \
# 0                     1         1         1       13.25        13.25
# 1                     2         2         1       16.00        16.00
# 2                     3         2         1       18.50        18.50
# 3                     4         2         1       20.75        20.75
# 4                     5         2         1       16.00        16.00
# ...                 ...       ...       ...         ...          ...
# 48615             48616     21348         1       16.75        16.75
# 48616             48617     21348         1       17.95        17.95
# 48617             48618     21348         1       12.00        12.00
# 48618             48619     21349         1       20.25        20.25
# 48619             48620     21350         1       12.75        12.75
#
#        pizza_size  pizza_category  hour
# 0             2.0               1    11
# 1             2.0               1    11
# ...

# %%
df2.corr()
# Out:
#                   order_details_id  order_id  quantity  unit_price  \
# order_details_id          1.000000  0.999990  0.003639   -0.003286
# order_id                  0.999990  1.000000  0.003621   -0.003323
# quantity                  0.003639  0.003621  1.000000    0.007142
# unit_price               -0.003286 -0.003323  0.007142    1.000000
# total_price              -0.000847 -0.000889  0.541926    0.836087
# pizza_size               -0.004237 -0.004270  0.012418    0.876817
# pizza_category           -0.006258 -0.006296 -0.012405   -0.001022
# hour                      0.006392  0.006419 -0.058092   -0.000677
#
#                   total_price  pizza_size  pizza_category      hour
# order_details_id    -0.000847   -0.004237       -0.006258  0.006392
# order_id            -0.000889   -0.004270       -0.006296  0.006419
# quantity             0.541926    0.012418       -0.012405 -0.058092
# unit_price           0.836087    0.876817       -0.001022 -0.000677
# ...

# %%
df.isnull().sum()
# Out:
# order_details_id     0
# order_id             0
# pizza_id             0
# quantity             0
# order_date           0
# order_time           0
# unit_price           0
# total_price          0
# pizza_size           0
# pizza_category       0
# pizza_ingredients    0
# pizza_name           0
# hour                 0
# dtype: int64

# %%
df['pizza_size']=df['pizza_size'].fillna(df['pizza_size'].mean())

# %%
x=df[["quantity","pizza_size","pizza_category","hour"]]
y=df["total_price"]

# %%
df
# Out:
#        order_details_id  order_id       pizza_id  quantity order_date  \
# 0                     1         1     hawaiian_m         1 2015-01-01
# 1                     2         2  classic_dlx_m         1 2015-01-01
# 2                     3         2  five_cheese_l         1 2015-01-01
# 3                     4         2    ital_supr_l         1 2015-01-01
# 4                     5         2     mexicana_m         1 2015-01-01
# ...                 ...       ...            ...       ...        ...
# 48615             48616     21348  ckn_alfredo_m         1 2015-12-31
# 48616             48617     21348  four_cheese_l         1 2015-12-31
# 48617             48618     21348   napolitana_s         1 2015-12-31
# 48618             48619     21349     mexicana_l         1 2015-12-31
# 48619             48620     21350      bbq_ckn_s         1 2015-12-31
#
#                order_time  unit_price  total_price  pizza_size  \
# ...

# %%
df2=df.select_dtypes(["int", "float"])
df2
# Out:
#        order_details_id  order_id  quantity  unit_price  total_price  \
# 0                     1         1         1       13.25        13.25
# 1                     2         2         1       16.00        16.00
# 2                     3         2         1       18.50        18.50
# 3                     4         2         1       20.75        20.75
# 4                     5         2         1       16.00        16.00
# ...                 ...       ...       ...         ...          ...
# 48615             48616     21348         1       16.75        16.75
# 48616             48617     21348         1       17.95        17.95
# 48617             48618     21348         1       12.00        12.00
# 48618             48619     21349         1       20.25        20.25
# 48619             48620     21350         1       12.75        12.75
#
#        pizza_size  pizza_category  hour
# 0             2.0               1    11
# 1             2.0               1    11
# ...

# %%
df2.corr()
# Out:
#                   order_details_id  order_id  quantity  unit_price  \
# order_details_id          1.000000  0.999990  0.003639   -0.003286
# order_id                  0.999990  1.000000  0.003621   -0.003323
# quantity                  0.003639  0.003621  1.000000    0.007142
# unit_price               -0.003286 -0.003323  0.007142    1.000000
# total_price              -0.000847 -0.000889  0.541926    0.836087
# pizza_size               -0.004237 -0.004270  0.012418    0.876817
# pizza_category           -0.006258 -0.006296 -0.012405   -0.001022
# hour                      0.006392  0.006419 -0.058092   -0.000677
#
#                   total_price  pizza_size  pizza_category      hour
# order_details_id    -0.000847   -0.004237       -0.006258  0.006392
# order_id            -0.000889   -0.004270       -0.006296  0.006419
# quantity             0.541926    0.012418       -0.012405 -0.058092
# unit_price           0.836087    0.876817       -0.001022 -0.000677
# ...

# %%
df.isnull().sum()
# Out:
# order_details_id     0
# order_id             0
# pizza_id             0
# quantity             0
# order_date           0
# order_time           0
# unit_price           0
# total_price          0
# pizza_size           0
# pizza_category       0
# pizza_ingredients    0
# pizza_name           0
# hour                 0
# dtype: int64

# %%
x=df[["quantity","pizza_size","pizza_category","hour"]]
y=df["total_price"]

# %%
from sklearn import linear_model

# %%
regr=linear_model.LinearRegression()
regr.fit(x,y)
# Out:
# LinearRegression()

# %%
df['pizza_size'].unique()
# Out:
# array([2.        , 3.        , 1.        , 4.        , 2.11271403])

# %%
df['pizza_category'].unique()
# Out:
# array([1, 3, 2, 0])

# %%
predicted=regr.predict([[1,5,2,11]])
predicted
# Out:
# C:\Users\ABHISHEK YADAV\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([27.60673788])

# %%
print(predicted)
# Out:
# [27.60673788]

# %%
predicted2=regr.predict(x)
predicted2
# Out:
# array([16.09594919, 16.09594919, 19.79986548, ..., 12.24273961,
#        19.81122039, 12.3246121 ], shape=(48620,))

# %%
from sklearn.metrics import r2_score
print(r2_score(y,predicted2))
# Out:
# 0.8268362241317218
