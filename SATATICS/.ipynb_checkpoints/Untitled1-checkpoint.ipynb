# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(42)

n = 200

car_names = ["ritz", "sx4", "ciaz", "wagon r", "swift", "verna", "city", "i20", "baleno", "creta"]
fuel_types = ["Petrol", "Diesel","CNG","Electric"]
seller_types = ["Dealer", "Individual"]
transmissions = ["Manual", "Automatic"]

data = {
    "Car_Name": np.random.choice(car_names, n),
    "Year": np.random.randint(2005, 2022, n),
    "Present_Price": np.round(np.random.uniform(3, 20, n), 2),
    "Kms_Driven": np.random.randint(5000, 150000, n),
    "Fuel_Type": np.random.choice(fuel_types, n),
    "Seller_Type": np.random.choice(seller_types, n),
    "Transmission": np.random.choice(transmissions, n),
    "Owner": np.random.randint(0, 3, n)
}

df = pd.DataFrame(data)
# Selling price = Present price ka 50%–90%
df["Selling_Price"] = np.round(df["Present_Price"] * np.random.uniform(0.5, 0.9, n), 2)

# Save file
df.to_csv("car_price_dataset_200_rows.csv", index=False)

print(df.head())
# Out:
#   Car_Name  Year  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0     city  2015           6.33       80745    Petrol  Individual
# 1  wagon r  2020           4.18       99456    Petrol  Individual
# 2      i20  2020           4.71       58413    Diesel      Dealer
# 3    swift  2005           3.31      102239    Petrol  Individual
# 4     city  2013           4.61       47318    Diesel      Dealer
#
#   Transmission  Owner  Selling_Price
# 0    Automatic      2           5.05
# 1       Manual      0           2.36
# 2       Manual      2           3.90
# 3       Manual      1           2.76
# 4    Automatic      2           3.24

# %%
df
# Out:
#     Car_Name  Year  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0       city  2015           6.33       80745    Petrol  Individual
# 1    wagon r  2020           4.18       99456    Petrol  Individual
# 2        i20  2020           4.71       58413    Diesel      Dealer
# 3      swift  2005           3.31      102239    Petrol  Individual
# 4       city  2013           4.61       47318    Diesel      Dealer
# ..       ...   ...            ...         ...       ...         ...
# 195      i20  2005           3.25       91740       CNG  Individual
# 196    swift  2005           8.96       20524    Diesel  Individual
# 197  wagon r  2012          13.03      136149  Electric  Individual
# 198      sx4  2014           9.67      130501    Petrol      Dealer
# 199    verna  2015          10.44       25611       CNG      Dealer
#
#     Transmission  Owner  Selling_Price
# 0      Automatic      2           5.05
# 1         Manual      0           2.36
# 2         Manual      2           3.90
# 3         Manual      1           2.76
# 4      Automatic      2           3.24
# ..           ...    ...            ...
# 195       Manual      2           1.98
# 196    Automatic      1           6.60
# 197    Automatic      1          11.27
# 198       Manual      2           5.65
# 199    Automatic      0           7.82
#
# [200 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       200 non-null    object
#  1   Year           200 non-null    int32
#  2   Present_Price  200 non-null    float64
#  3   Kms_Driven     200 non-null    int32
#  4   Fuel_Type      200 non-null    object
#  5   Seller_Type    200 non-null    object
#  6   Transmission   200 non-null    object
#  7   Owner          200 non-null    int32
#  8   Selling_Price  200 non-null    float64
# dtypes: float64(2), int32(3), object(4)
# memory usage: 11.8+ KB

# %%
df['Fuel_Type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'Electric', 'CNG'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# Selling_Price    0
# dtype: int64

# %%
df['Owner'].value_counts()
# Out:
# Owner
# 0    78
# 2    62
# 1    60
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
encoder= LabelEncoder()
df['Furl_Type']=encoder.fit_transform(df['Fuel_Type'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       200 non-null    object
#  1   Year           200 non-null    int32
#  2   Present_Price  200 non-null    float64
#  3   Kms_Driven     200 non-null    int32
#  4   Fuel_Type      200 non-null    object
#  5   Seller_Type    200 non-null    object
#  6   Transmission   200 non-null    object
#  7   Owner          200 non-null    int32
#  8   Selling_Price  200 non-null    float64
#  9   Furl_Type      200 non-null    int64
# dtypes: float64(2), int32(3), int64(1), object(4)
# memory usage: 13.4+ KB

# %%
df.duplicated().count()
# Out:
# np.int64(200)

# %%
df2=df.select_dtypes(['int','float'])
df2
# Out:
#      Year  Present_Price  Kms_Driven  Owner  Selling_Price  Furl_Type
# 0    2015           6.33       80745      2           5.05          3
# 1    2020           4.18       99456      0           2.36          3
# 2    2020           4.71       58413      2           3.90          1
# 3    2005           3.31      102239      1           2.76          3
# 4    2013           4.61       47318      2           3.24          1
# ..    ...            ...         ...    ...            ...        ...
# 195  2005           3.25       91740      2           1.98          0
# 196  2005           8.96       20524      1           6.60          1
# 197  2012          13.03      136149      1          11.27          2
# 198  2014           9.67      130501      2           5.65          3
# 199  2015          10.44       25611      0           7.82          0
#
# [200 rows x 6 columns]

# %%
df2.corr()
# Out:
#                    Year  Present_Price  Kms_Driven     Owner  Selling_Price  \
# Year           1.000000       0.132120    0.071628 -0.006717       0.189547
# Present_Price  0.132120       1.000000    0.010887  0.059441       0.920310
# Kms_Driven     0.071628       0.010887    1.000000  0.083691       0.007336
# Owner         -0.006717       0.059441    0.083691  1.000000       0.034937
# Selling_Price  0.189547       0.920310    0.007336  0.034937       1.000000
# Furl_Type      0.075084       0.045658   -0.030302 -0.010179       0.042144
#
#                Furl_Type
# Year            0.075084
# Present_Price   0.045658
# Kms_Driven     -0.030302
# Owner          -0.010179
# Selling_Price   0.042144
# Furl_Type       1.000000

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           200 non-null    int32
#  1   Present_Price  200 non-null    float64
#  2   Kms_Driven     200 non-null    int32
#  3   Owner          200 non-null    int32
#  4   Selling_Price  200 non-null    float64
#  5   Furl_Type      200 non-null    int64
# dtypes: float64(2), int32(3), int64(1)
# memory usage: 7.2 KB

# %%
x=df[['Year','Present_Price','Fuel_Type','Kms_Driven']]
y=df2['Selling_Price']

# %%
from sklearn import linear_model

# %%
regr=linear_model.LinearRegression()
regr.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15748\1536503348.py in ?()
#       1 regr=linear_model.LinearRegression()
# ----> 2 regr.fit(x,y)
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1361                 skip_parameter_validation=(
#    1362                     prefer_skip_nested_validation or global_skip_validation
#    1363                 )
#    1364             ):
# -> 1365                 return fit_method(estimator, *args, **kwargs)
#
# ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py in ?(self, X, y, sample_weight)
#     614         n_jobs_ = self.n_jobs
#     615
#     616         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     617
# --> 618         X, y = validate_data(
#     619             self,
#     620             X,
#     621             y,
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2967             if "estimator" not in check_y_params:
#    2968                 check_y_params = {**default_check_params, **check_y_params}
#    2969             y = check_array(y, input_name="y", **check_y_params)
#    2970         else:
# -> 2971             X, y = check_X_y(X, y, **check_params)
#    2972         out = X, y
#    2973
#    2974     if not no_val_X and check_params.get("ensure_2d", True):
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py in ?(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1364         )
#    1365
#    1366     ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
#    1367
# -> 1368     X = check_array(
#    1369         X,
#    1370         accept_sparse=accept_sparse,
#    1371         accept_large_sparse=accept_large_sparse,
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1050                         )
#    1051                     array = xp.astype(array, dtype, copy=False)
#    1052                 else:
#    1053                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1054             except ComplexWarning as complex_warning:
#    1055                 raise ValueError(
#    1056                     "Complex data not supported\n{}\n".format(array)
#    1057                 ) from complex_warning
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     753         # Use NumPy API to support order
#     754         if copy is True:
#     755             array = numpy.array(array, order=order, dtype=dtype)
#     756         else:
# --> 757             array = numpy.asarray(array, order=order, dtype=dtype)
#     758
#     759         # At this point array is a NumPy ndarray. We convert it to an array
#     760         # container that is consistent with the input's namespace.
#
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2167             )
#    2168         values = self._values
#    2169         if copy is None:
#    2170             # Note: branch avoids `copy=None` for NumPy 1.x support
# -> 2171             arr = np.asarray(values, dtype=dtype)
#    2172         else:
#    2173             arr = np.array(values, dtype=dtype, copy=copy)
#    2174
#
# ValueError: could not convert string to float: 'Petrol'

# %%
df2["Fuel_Type"].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Fuel_Type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df2["Fuel_Type"].unique()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Fuel_Type'
