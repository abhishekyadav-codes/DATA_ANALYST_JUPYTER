# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\ABHISHEK YADAV\Downloads\employee_salary_dataset.csv")
a=df.groupby('Department')
# for i,j in a:
    # print(i)
    # print(j)
y=a['Monthly_Salary'].sum()
y
# z=pd.DataFrame(a)
# z
# z
# k=z('Monthly_Salary').count()
# k

a=df.groupby('Department')
a
df
# Out:
#     EmployeeID         Name  Department  Experience_Years Education_Level  \
# 0            1   Employee_1   Marketing                15          Master
# 1            2   Employee_2  Operations                 7        Bachelor
# 2            3   Employee_3          IT                12     High School
# 3            4   Employee_4  Operations                 8             PhD
# 4            5   Employee_5  Operations                15          Master
# 5            6   Employee_6     Finance                 3     High School
# 6            7   Employee_7          IT                14             PhD
# 7            8   Employee_8          IT                17             PhD
# 8            9   Employee_9          IT                 4        Bachelor
# 9           10  Employee_10  Operations                18     High School
# 10          11  Employee_11   Marketing                 8             PhD
# 11          12  Employee_12          IT                 4          Master
# ...

# %%
for i,j in a:
    print(i)
    print(j)
# Out:
# Finance
#     EmployeeID         Name Department  Experience_Years Education_Level  Age  \
# 5            6   Employee_6    Finance                 3     High School   50
# 13          14  Employee_14    Finance                 6        Bachelor   27
# 15          16  Employee_16    Finance                 4     High School   49
# 20          21  Employee_21    Finance                 4          Master   46
# 27          28  Employee_28    Finance                16          Master   29
# 39          40  Employee_40    Finance                12        Bachelor   38
# 43          44  Employee_44    Finance                17          Master   44
# 44          45  Employee_45    Finance                 8          Master   53
# 46          47  Employee_47    Finance                 3          Master   22
# 48          49  Employee_49    Finance                 5             PhD   23
#
#     Gender       City  Monthly_Salary
# 5     Male     Mumbai           65818
# ...

# %%
a['Monthly_Salary'].sum()
# Out:
# Department
# Finance        672619
# HR             580616
# IT             765205
# Marketing     1253601
# Operations     842399
# Name: Monthly_Salary, dtype: int64

# %%
pivot = df.pivot_table(
    index='Department',
    columns='Education_Level',
    values='EmployeeID',
    aggfunc='count',
    fill_value=0
)
pivot
# Out:
# Education_Level  Bachelor  High School  Master  PhD
# Department
# Finance                 2            2       5    1
# HR                      1            1       2    3
# IT                      3            2       3    2
# Marketing               2            5       4    2
# Operations              1            2       5    2

# %%
ipl_data = {'Team':['Riders','Riders','Devils','Devils','Kings','Kings','Kings','Kings','Riders','Royals','Royals','Royals'],
            'Rank':[1,2,2,3,3,4,1,1,2,4,1,2],
            'Year':[2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
            'Points':[876,789,863,673,741,812,756,788,694,701,884,690],
            
           }
df2= pd.DataFrame(ipl_data)
df2
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    Kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     884
# 11  Royals     2  2017     690

# %%
df2.pivot_table(index='Team',columns='Year',aggfunc='count',fill_value=0,margins=True)
# Out:
#        Points                    Rank
# Year     2014 2015 2016 2017 All 2014 2015 2016 2017 All
# Team
# Devils      1    1    0    0   2    1    1    0    0   2
# Kings       1    1    1    1   4    1    1    1    1   4
# Riders      1    1    1    0   3    1    1    1    0   3
# Royals      1    1    0    1   3    1    1    0    1   3
# All         4    4    2    2  12    4    4    2    2  12
